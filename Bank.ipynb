# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/bluenex/WekaLearningDataset/master/bank/bank-data.csv'
arquivo = pd.read_csv(url)
arquivo.head()
# Out:
#         id  age     sex      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# 2         YES       NO   NO
# 3         YES       NO   NO
# 4          NO       NO   NO

# %%
# Informações gerais sobre o dataset
print(arquivo.info())

# Descrição estatística das variáveis numéricas
print(arquivo.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           600 non-null    object
#  1   age          600 non-null    int64
#  2   sex          600 non-null    object
#  3   region       600 non-null    object
#  4   income       600 non-null    float64
#  5   married      600 non-null    object
#  6   children     600 non-null    int64
#  7   car          600 non-null    object
#  8   save_act     600 non-null    object
#  9   current_act  600 non-null    object
#  10  mortgage     600 non-null    object
#  11  pep          600 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 56.4+ KB
# None
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
import matplotlib.pyplot as plt
arquivo.hist(figsize=(20, 15), bins=20)
plt.show()

# %%
print(arquivo['region'].value_counts())
# Out:
# region
# INNER_CITY    269
# TOWN          173
# RURAL          96
# SUBURBAN       62
# Name: count, dtype: int64

# %%
arquivo['sex'] = arquivo['sex'].replace('FEMALE', 0)
arquivo['sex'] = arquivo['sex'].replace('MALE', 1)

arquivo['region'] = arquivo['region'].replace('INNER_CITY', 1)
arquivo['region'] = arquivo['region'].replace('TOWN', 2)
arquivo['region'] = arquivo['region'].replace('RURAL', 3)
arquivo['region'] = arquivo['region'].replace('SUBURBAN', 4)

arquivo['married'] = arquivo['married'].replace('NO', 0)
arquivo['married'] = arquivo['married'].replace('YES', 1)

arquivo['car'] = arquivo['car'].replace('NO', 0)
arquivo['car'] = arquivo['car'].replace('YES', 1)

arquivo['save_act'] = arquivo['save_act'].replace('NO', 0)
arquivo['save_act'] = arquivo['save_act'].replace('YES', 1)

arquivo['current_act'] = arquivo['current_act'].replace('NO', 0)
arquivo['current_act'] = arquivo['current_act'].replace('YES', 1)

arquivo['mortgage'] = arquivo['mortgage'].replace('NO', 0)
arquivo['mortgage'] = arquivo['mortgage'].replace('YES', 1)

arquivo['pep'] = arquivo['pep'].replace('NO', 0)
arquivo['pep'] = arquivo['pep'].replace('YES', 1)
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['sex'] = arquivo['sex'].replace('MALE', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['region'] = arquivo['region'].replace('SUBURBAN', 4)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['married'] = arquivo['married'].replace('YES', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['car'] = arquivo['car'].replace('YES', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['save_act'] = arquivo['save_act'].replace('YES', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['current_act'] = arquivo['current_act'].replace('YES', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['mortgage'] = arquivo['mortgage'].replace('YES', 1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_10520\1410898942.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['pep'] = arquivo['pep'].replace('YES', 1)

# %%
import matplotlib.pyplot as plt
arquivo.hist(figsize=(20, 15), bins=20)
plt.show()

# %%
arquivo.boxplot(figsize=(20, 10), rot=90)
plt.show()

# %%
print(arquivo['current_act'].value_counts())
# Out:
# current_act
# 1    455
# 0    145
# Name: count, dtype: int64

# %%
arquivo['rendaPercapta'] = arquivo['income'] / (1 + arquivo['married'] + arquivo['children'])
